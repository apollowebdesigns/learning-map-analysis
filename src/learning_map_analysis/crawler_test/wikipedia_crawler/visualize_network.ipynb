# %%
from graph_builder import Network
        
n = Network("wikipedia_network.json", 20)
# Out:
# Top nodes by PageRank:
# Node: https://en.wikipedia.org/wiki/Economic analysis of climate change, PageRank: 5.725177606402848e-05
# Node: https://en.wikipedia.org/wiki/Climate change, PageRank: 5.710857653353766e-05
# Node: https://en.wikipedia.org/wiki/Climate change mitigation, PageRank: 4.7852447267882394e-05
# Node: https://en.wikipedia.org/wiki/ISSN (identifier), PageRank: 4.685439131194235e-05
# Node: https://en.wikipedia.org/wiki/Environmental effects of transport, PageRank: 4.582966977530466e-05
# Node: https://en.wikipedia.org/wiki/Intergovernmental Panel on Climate Change, PageRank: 4.502164769118379e-05
# Node: https://en.wikipedia.org/wiki/Climate variability and change, PageRank: 4.4769053474865816e-05
# Node: https://en.wikipedia.org/wiki/Doi (identifier), PageRank: 4.3922965215019846e-05
# Node: https://en.wikipedia.org/wiki/Earth's energy budget, PageRank: 4.340182339976594e-05
# Node: https://en.wikipedia.org/wiki/Carbon price, PageRank: 4.1816273951766024e-05
# ...

# %%
from graph_builder import Network
        
n = Network("es_wikipedia_network.json", 20)
# Out:
# Top nodes by PageRank:
# Node: https://es.wikipedia.org/wiki/Wikidata, PageRank: 0.0002372951303311013
# Node: https://es.wikipedia.org/wiki/Control de autoridades, PageRank: 0.00023395805798112935
# Node: https://es.wikipedia.org/wiki/Wikimedia Commons, PageRank: 0.00016101417122208096
# Node: https://es.wikipedia.org/wiki/Dióxido de carbono, PageRank: 0.00013949138622218447
# Node: https://es.wikipedia.org/wiki/Enciclopedia Británica, PageRank: 0.00013279937707004835
# Node: https://es.wikipedia.org/wiki/Gas de efecto invernadero, PageRank: 0.00012985825661682173
# Node: https://es.wikipedia.org/wiki/Grado Celsius, PageRank: 0.00012446887734738878
# Node: https://es.wikipedia.org/wiki/Gemeinsame Normdatei, PageRank: 0.00012190188499144877
# Node: https://es.wikipedia.org/wiki/Corriente marina, PageRank: 0.00012025862235020669
# Node: https://es.wikipedia.org/wiki/Science, PageRank: 0.00011976864935117274
# Node: https://es.wikipedia.org/wiki/ISBN, PageRank: 0.00011975494701059348
# ...

# %%
n = Network("wikibook_network.json", 10)

# %%
n = Network("wikipedia_first_link_network.json", 20)
